# %%
import pandas as pd

# %%
#load the data 
train = pd.read_csv('D:/edwisor_details/project/cab_fare_1/transformed_train_df.csv',sep=',')
test = pd.read_csv('D:/edwisor_details/project/cab_fare_1/transformed_test_df.csv', sep=',')

# %%
## setting up the environment
from pycaret.regression import *

# %%
#model_setup = setup(data=train, target='default', session_id=123)
#intialize the setup
exp_reg = setup(train, target = 'fare_amount')
# Out:
# <style  type="text/css" >
# #T_dc6a4974_f7a3_11eb_925d_94e979dccff7row42_col1{
#             background-color:  lightgreen;
#         }</style><table id="T_dc6a4974_f7a3_11eb_925d_94e979dccff7" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_dc6a4974_f7a3_11eb_925d_94e979dccff7level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_dc6a4974_f7a3_11eb_925d_94e979dccff7row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_dc6a4974_f7a3_11eb_925d_94e979dccff7row0_col1" class="data row0 col1" >1709</td>
#             </tr>
#             <tr>
#                         <th id="T_dc6a4974_f7a3_11eb_925d_94e979dccff7level0_row1" class="row_heading level0 row1" >1</th>
# ...

# %%
compare_models()
# Out:
# <style  type="text/css" >
#     #T_4de0cf10_f7a4_11eb_849b_94e979dccff7 th {
#           text-align: left;
# ...

# %%
gbr = create_model('gbr')
# Out:
# <style  type="text/css" >
# #T_e1e7ac74_f7a4_11eb_89aa_94e979dccff7row10_col0,#T_e1e7ac74_f7a4_11eb_89aa_94e979dccff7row10_col1,#T_e1e7ac74_f7a4_11eb_89aa_94e979dccff7row10_col2,#T_e1e7ac74_f7a4_11eb_89aa_94e979dccff7row10_col3,#T_e1e7ac74_f7a4_11eb_89aa_94e979dccff7row10_col4,#T_e1e7ac74_f7a4_11eb_89aa_94e979dccff7row10_col5{
#             background:  yellow;
#         }</style><table id="T_e1e7ac74_f7a4_11eb_89aa_94e979dccff7" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >MAE</th>        <th class="col_heading level0 col1" >MSE</th>        <th class="col_heading level0 col2" >RMSE</th>        <th class="col_heading level0 col3" >R2</th>        <th class="col_heading level0 col4" >RMSLE</th>        <th class="col_heading level0 col5" >MAPE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e1e7ac74_f7a4_11eb_89aa_94e979dccff7level0_row0" class="row_heading level0 row0" >0</th>
# ...

# %%
tuned_gbr = tune_model(gbr)
# Out:
# <style  type="text/css" >
# #T_0f5d32b8_f7a5_11eb_ba4a_94e979dccff7row10_col0,#T_0f5d32b8_f7a5_11eb_ba4a_94e979dccff7row10_col1,#T_0f5d32b8_f7a5_11eb_ba4a_94e979dccff7row10_col2,#T_0f5d32b8_f7a5_11eb_ba4a_94e979dccff7row10_col3,#T_0f5d32b8_f7a5_11eb_ba4a_94e979dccff7row10_col4,#T_0f5d32b8_f7a5_11eb_ba4a_94e979dccff7row10_col5{
#             background:  yellow;
#         }</style><table id="T_0f5d32b8_f7a5_11eb_ba4a_94e979dccff7" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >MAE</th>        <th class="col_heading level0 col1" >MSE</th>        <th class="col_heading level0 col2" >RMSE</th>        <th class="col_heading level0 col3" >R2</th>        <th class="col_heading level0 col4" >RMSLE</th>        <th class="col_heading level0 col5" >MAPE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_0f5d32b8_f7a5_11eb_ba4a_94e979dccff7level0_row0" class="row_heading level0 row0" >0</th>
# ...

# %%
plot_model(tuned_gbr)

# %%
evaluate_model(tuned_gbr)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Hyperparameters', 'param…
